# %% [markdown]
# ### Imports

# %%
from mesa import Model, Agent
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
import numpy as np
import random

# %% [markdown]
# ### Variables
#
# Estas son las dimensiones del área de simulación, la cantidad de agentes, cajas totales, el número máximo de pasos para la simulación y la cantidad máxima de cajas por celda.

# %%
random.seed(67890)
WIDTH, HEIGHT = 20, 20
NUM_AGENTS = 5
TOTAL_BOXES = 200
MAX_STEPS = 100000
MAX_BOXES_PER_CELL = 5

# %% [markdown]
# ### Clase Cell
#
# Representa una celda en la cuadrícula. Cada celda lleva un conteo de cuántas cajas contiene.

# %%
class Cell:
    def __init__(self):
        self.box_count = 0

    @property
    def is_full(self):
        return self.box_count >= MAX_BOXES_PER_CELL

    @property
    def is_empty(self):
        return self.box_count == 0

# %% [markdown]
# ### Box Organizing Agent
# Define el comportamiento de un agente en la simulación. Cada agente puede llevar una caja a la vez (self.carrying_box). Los métodos pick_box y place_box definen cómo recogen y depositan cajas, respectivamente, y move mueve al agente a una celda vecina aleatoria.

# %%
class BoxOrganizingAgent(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.carrying_box = False

    def step(self):
        if self.carrying_box:
            self.place_box()
        else:
            self.pick_box()

    def pick_box(self):
        cells = self.model.grid.get_neighborhood(self.pos, moore=False, include_center=True)
        cell_with_boxes = [(cell, self.model.cell_state[cell]) for cell in cells if 0 < self.model.cell_state[cell] < MAX_BOXES_PER_CELL]
        if cell_with_boxes:
            target_cell = min(cell_with_boxes, key=lambda x: x[1])[0]
            self.model.cell_state[target_cell] -= 1
            self.carrying_box = True
            print(f"Agente {self.unique_id} recogió una caja de {target_cell}")
        else:
            print(f"Agente {self.unique_id} no encontró caja para recoger")
        self.move()

    def place_box(self):
        cells = self.model.grid.get_neighborhood(self.pos, moore=False, include_center=True)
        cell_with_space = [(cell, self.model.cell_state[cell]) for cell in cells if self.model.cell_state[cell] < MAX_BOXES_PER_CELL]
        if cell_with_space:
            target_cell = max(cell_with_space, key=lambda x: x[1])[0]
            self.model.cell_state[target_cell] += 1
            self.carrying_box = False
            print(f"Agente {self.unique_id} colocó una caja en {target_cell}")
        else:
            print(f"Agente {self.unique_id} no encontró dónde colocar la caja")
        self.move()

    def move(self):
        possible_moves = [cell for cell in self.model.grid.get_neighborhood(self.pos, moore=False, include_center=False)]
        if possible_moves:
            new_position = random.choice(possible_moves)
            self.model.grid.move_agent(self, new_position)
            print(f"Agente {self.unique_id} se movió a {new_position}")

# %% [markdown]
# ### Box Organizing Model
# Es el modelo de la simulación. Contiene una cuadrícula (MultiGrid) donde se colocan los agentes y las celdas, y un planificador (RandomActivation) que activa a los agentes de manera aleatoria. Inicializa el estado de las celdas y coloca las cajas al principio. El método step avanza la simulación un paso, activando cada agente y verificando si se ha alcanzado el objetivo de la simulación.

# %%
class BoxOrganizingModel(Model):
    def __init__(self, width, height, num_agents, total_boxes):
        self.grid = MultiGrid(width, height, torus=False)
        self.schedule = RandomActivation(self)
        self.running = True
        self.cell_state = {(x, y): 0 for x in range(width) for y in range(height)}

        # Inicializar el DataCollector con la función get_grid
        self.datacollector = DataCollector(
            model_reporters={"Grid": self.get_grid, "Agents": self.get_agent_positions}
        )
        # Recopilar datos iniciales
        self.datacollector.collect(self)

        # Crear y colocar agentes
        for i in range(num_agents):
            agent = BoxOrganizingAgent(i, self)
            self.schedule.add(agent)
            x, y = random.randint(0, width - 1), random.randint(0, height - 1)
            self.grid.place_agent(agent, (x, y))

        # Colocar cajas en las celdas
        boxes_placed = 0
        while boxes_placed < total_boxes:
            x, y = random.randint(0, width - 1), random.randint(0, height - 1)
            boxes_to_add = random.randint(1, 3)  # Cantidad aleatoria de cajas entre 1 y 3

            # Verificar que no se exceda el número total de cajas
            if boxes_placed + boxes_to_add > total_boxes:
                boxes_to_add = total_boxes - boxes_placed

            # Asegurarse de no exceder el máximo por celda
            if self.cell_state[(x, y)] + boxes_to_add <= MAX_BOXES_PER_CELL:
                self.cell_state[(x, y)] += boxes_to_add
                boxes_placed += boxes_to_add

    def get_agent_positions(self):
        agent_positions = np.zeros((self.grid.width, self.grid.height))
        for agent in self.schedule.agents:
            x, y = agent.pos
            agent_positions[y][x] = 1  # Marcar la posición del agente
        return agent_positions
    
    def print_step_summary(self):
        print(f"Paso {self.schedule.steps}:")
        for agent in self.schedule.agents:
            print(f"  - Agente {agent.unique_id}: Posición {agent.pos}, Estado {'Con caja' if agent.carrying_box else 'Sin caja'}")


    def get_grid(self):
        grid = np.zeros((self.grid.width, self.grid.height))
        for (x, y), boxes in self.cell_state.items():
            grid[y][x] = boxes
        return grid

    def step(self):
        self.schedule.step()
        self.datacollector.collect(self)
        self.print_step_summary()

        if all(self.cell_state[cell] in [0, MAX_BOXES_PER_CELL] for cell in self.cell_state):
            self.running = False

# %% [markdown]
# ### Inicialización
#
# Se crea una instancia del modelo y se ejecuta hasta que se alcanza el número máximo de pasos o hasta que todas las celdas contienen 0 o 5 cajas. Al final, imprime el estado final de las celdas y un resumen.

# %%
# Definición del modelo y ejecución de la simulación
model = BoxOrganizingModel(WIDTH, HEIGHT, NUM_AGENTS, TOTAL_BOXES)
for _ in range(MAX_STEPS):
    if not model.running:
        break
    model.step()
# Out:
# Agente 2 recogió una caja de (8, 3)
# Agente 2 se movió a (7, 3)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (19, 7)
# Agente 0 recogió una caja de (7, 4)
# Agente 0 se movió a (7, 4)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (13, 15)
# Agente 4 recogió una caja de (15, 14)
# Agente 4 se movió a (16, 14)
# Paso 1:
#   - Agente 0: Posición (7, 4), Estado Con caja
#   - Agente 1: Posición (13, 15), Estado Sin caja
#   - Agente 2: Posición (7, 3), Estado Con caja
#   - Agente 3: Posición (19, 7), Estado Sin caja
#   - Agente 4: Posición (16, 14), Estado Con caja
# Agente 0 colocó una caja en (6, 4)
# Agente 0 se movió a (7, 5)
# Agente 2 colocó una caja en (6, 3)
# Agente 2 se movió a (7, 2)
# Agente 3 recogió una caja de (19, 6)
# Agente 3 se movió a (19, 6)
# Agente 4 colocó una caja en (16, 14)
# Agente 4 se movió a (16, 13)
# Agente 1 recogió una caja de (14, 15)
# Agente 1 se movió a (13, 14)
# Paso 2:
#   - Agente 0: Posición (7, 5), Estado Sin caja
#   - Agente 1: Posición (13, 14), Estado Con caja
#   - Agente 2: Posición (7, 2), Estado Sin caja
#   - Agente 3: Posición (19, 6), Estado Con caja
#   - Agente 4: Posición (16, 13), Estado Sin caja
# Agente 3 colocó una caja en (18, 6)
# Agente 3 se movió a (19, 7)
# Agente 2 recogió una caja de (7, 1)
# Agente 2 se movió a (8, 2)
# Agente 4 recogió una caja de (16, 14)
# Agente 4 se movió a (15, 13)
# Agente 1 colocó una caja en (14, 14)
# Agente 1 se movió a (14, 14)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 5)
# Paso 3:
#   - Agente 0: Posición (6, 5), Estado Sin caja
#   - Agente 1: Posición (14, 14), Estado Sin caja
#   - Agente 2: Posición (8, 2), Estado Con caja
#   - Agente 3: Posición (19, 7), Estado Sin caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (15, 12)
# Agente 0 recogió una caja de (6, 4)
# Agente 0 se movió a (7, 5)
# Agente 2 colocó una caja en (7, 2)
# Agente 2 se movió a (8, 1)
# Agente 1 recogió una caja de (14, 15)
# Agente 1 se movió a (13, 14)
# Agente 3 recogió una caja de (19, 6)
# Agente 3 se movió a (18, 7)
# Paso 4:
#   - Agente 0: Posición (7, 5), Estado Con caja
#   - Agente 1: Posición (13, 14), Estado Con caja
#   - Agente 2: Posición (8, 1), Estado Sin caja
#   - Agente 3: Posición (18, 7), Estado Con caja
#   - Agente 4: Posición (15, 12), Estado Sin caja
# Agente 2 recogió una caja de (9, 1)
# Agente 2 se movió a (8, 0)
# Agente 0 colocó una caja en (6, 5)
# Agente 0 se movió a (7, 6)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (15, 13)
# Agente 1 colocó una caja en (14, 14)
# Agente 1 se movió a (13, 13)
# Agente 3 colocó una caja en (17, 7)
# Agente 3 se movió a (18, 8)
# Paso 5:
#   - Agente 0: Posición (7, 6), Estado Sin caja
#   - Agente 1: Posición (13, 13), Estado Sin caja
#   - Agente 2: Posición (8, 0), Estado Con caja
#   - Agente 3: Posición (18, 8), Estado Sin caja
#   - Agente 4: Posición (15, 13), Estado Sin caja
# Agente 0 recogió una caja de (6, 6)
# Agente 0 se movió a (7, 5)
# Agente 3 recogió una caja de (17, 8)
# Agente 3 se movió a (18, 7)
# Agente 4 recogió una caja de (14, 13)
# Agente 4 se movió a (15, 14)
# Agente 2 colocó una caja en (9, 0)
# Agente 2 se movió a (9, 0)
# Agente 1 recogió una caja de (13, 13)
# Agente 1 se movió a (13, 14)
# Paso 6:
#   - Agente 0: Posición (7, 5), Estado Con caja
#   - Agente 1: Posición (13, 14), Estado Con caja
#   - Agente 2: Posición (9, 0), Estado Sin caja
#   - Agente 3: Posición (18, 7), Estado Con caja
#   - Agente 4: Posición (15, 14), Estado Con caja
# Agente 2 recogió una caja de (9, 0)
# Agente 2 se movió a (8, 0)
# Agente 1 colocó una caja en (13, 13)
# Agente 1 se movió a (13, 13)
# Agente 4 colocó una caja en (16, 14)
# Agente 4 se movió a (14, 14)
# Agente 3 colocó una caja en (17, 7)
# Agente 3 se movió a (17, 7)
# Agente 0 colocó una caja en (6, 5)
# Agente 0 se movió a (8, 5)
# Paso 7:
#   - Agente 0: Posición (8, 5), Estado Sin caja
#   - Agente 1: Posición (13, 13), Estado Sin caja
#   - Agente 2: Posición (8, 0), Estado Con caja
#   - Agente 3: Posición (17, 7), Estado Sin caja
#   - Agente 4: Posición (14, 14), Estado Sin caja
# Agente 2 colocó una caja en (9, 0)
# Agente 2 se movió a (7, 0)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 6)
# Agente 1 recogió una caja de (13, 13)
# Agente 1 se movió a (12, 13)
# Agente 3 recogió una caja de (16, 7)
# Agente 3 se movió a (17, 8)
# Agente 4 recogió una caja de (14, 13)
# Agente 4 se movió a (14, 15)
# Paso 8:
#   - Agente 0: Posición (8, 6), Estado Sin caja
#   - Agente 1: Posición (12, 13), Estado Con caja
#   - Agente 2: Posición (7, 0), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Con caja
#   - Agente 4: Posición (14, 15), Estado Con caja
# Agente 0 recogió una caja de (8, 7)
# Agente 0 se movió a (7, 6)
# Agente 1 colocó una caja en (12, 12)
# Agente 1 se movió a (12, 14)
# Agente 3 colocó una caja en (17, 9)
# Agente 3 se movió a (18, 8)
# Agente 2 recogió una caja de (7, 1)
# Agente 2 se movió a (8, 0)
# Agente 4 colocó una caja en (13, 15)
# Agente 4 se movió a (13, 15)
# Paso 9:
#   - Agente 0: Posición (7, 6), Estado Con caja
#   - Agente 1: Posición (12, 14), Estado Sin caja
#   - Agente 2: Posición (8, 0), Estado Con caja
#   - Agente 3: Posición (18, 8), Estado Sin caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 2 colocó una caja en (9, 0)
# Agente 2 se movió a (9, 0)
# Agente 4 recogió una caja de (13, 15)
# Agente 4 se movió a (14, 15)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (12, 13)
# Agente 0 colocó una caja en (6, 6)
# Agente 0 se movió a (8, 6)
# Agente 3 recogió una caja de (17, 8)
# Agente 3 se movió a (18, 9)
# Paso 10:
#   - Agente 0: Posición (8, 6), Estado Sin caja
#   - Agente 1: Posición (12, 13), Estado Sin caja
#   - Agente 2: Posición (9, 0), Estado Sin caja
#   - Agente 3: Posición (18, 9), Estado Con caja
#   - Agente 4: Posición (14, 15), Estado Con caja
# Agente 1 recogió una caja de (13, 13)
# Agente 1 se movió a (12, 12)
# Agente 0 recogió una caja de (8, 7)
# Agente 0 se movió a (8, 5)
# Agente 4 colocó una caja en (13, 15)
# Agente 4 se movió a (14, 16)
# Agente 3 colocó una caja en (17, 9)
# Agente 3 se movió a (18, 10)
# Agente 2 recogió una caja de (9, 0)
# Agente 2 se movió a (9, 1)
# Paso 11:
#   - Agente 0: Posición (8, 5), Estado Con caja
#   - Agente 1: Posición (12, 12), Estado Con caja
#   - Agente 2: Posición (9, 1), Estado Con caja
#   - Agente 3: Posición (18, 10), Estado Sin caja
#   - Agente 4: Posición (14, 16), Estado Sin caja
# Agente 2 colocó una caja en (9, 0)
# Agente 2 se movió a (10, 1)
# Agente 3 recogió una caja de (18, 11)
# Agente 3 se movió a (17, 10)
# Agente 0 colocó una caja en (7, 5)
# Agente 0 se movió a (8, 4)
# Agente 1 colocó una caja en (12, 12)
# Agente 1 se movió a (12, 11)
# Agente 4 recogió una caja de (14, 17)
# Agente 4 se movió a (14, 15)
# Paso 12:
#   - Agente 0: Posición (8, 4), Estado Sin caja
#   - Agente 1: Posición (12, 11), Estado Sin caja
#   - Agente 2: Posición (10, 1), Estado Sin caja
#   - Agente 3: Posición (17, 10), Estado Con caja
#   - Agente 4: Posición (14, 15), Estado Con caja
# Agente 4 colocó una caja en (13, 15)
# Agente 4 se movió a (15, 15)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 3)
# Agente 1 recogió una caja de (12, 11)
# Agente 1 se movió a (12, 10)
# Agente 2 recogió una caja de (10, 1)
# Agente 2 se movió a (10, 0)
# Agente 3 colocó una caja en (16, 10)
# Agente 3 se movió a (17, 11)
# Paso 13:
#   - Agente 0: Posición (8, 3), Estado Sin caja
#   - Agente 1: Posición (12, 10), Estado Con caja
#   - Agente 2: Posición (10, 0), Estado Con caja
#   - Agente 3: Posición (17, 11), Estado Sin caja
#   - Agente 4: Posición (15, 15), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 4)
# Agente 2 colocó una caja en (9, 0)
# Agente 2 se movió a (11, 0)
# Agente 1 colocó una caja en (11, 10)
# Agente 1 se movió a (11, 10)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 15)
# Agente 3 recogió una caja de (18, 11)
# Agente 3 se movió a (17, 10)
# Paso 14:
#   - Agente 0: Posición (8, 4), Estado Sin caja
#   - Agente 1: Posición (11, 10), Estado Sin caja
#   - Agente 2: Posición (11, 0), Estado Sin caja
#   - Agente 3: Posición (17, 10), Estado Con caja
#   - Agente 4: Posición (14, 15), Estado Sin caja
# Agente 1 recogió una caja de (11, 10)
# Agente 1 se movió a (12, 10)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 4)
# Agente 4 recogió una caja de (13, 15)
# Agente 4 se movió a (14, 14)
# Agente 2 recogió una caja de (11, 1)
# Agente 2 se movió a (10, 0)
# Agente 3 colocó una caja en (16, 10)
# Agente 3 se movió a (16, 10)
# Paso 15:
#   - Agente 0: Posición (7, 4), Estado Sin caja
#   - Agente 1: Posición (12, 10), Estado Con caja
#   - Agente 2: Posición (10, 0), Estado Con caja
#   - Agente 3: Posición (16, 10), Estado Sin caja
#   - Agente 4: Posición (14, 14), Estado Con caja
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (13, 14)
# Agente 0 recogió una caja de (7, 5)
# Agente 0 se movió a (7, 3)
# Agente 1 colocó una caja en (11, 10)
# Agente 1 se movió a (13, 10)
# Agente 2 colocó una caja en (9, 0)
# Agente 2 se movió a (9, 0)
# Agente 3 recogió una caja de (16, 10)
# Agente 3 se movió a (16, 9)
# Paso 16:
#   - Agente 0: Posición (7, 3), Estado Con caja
#   - Agente 1: Posición (13, 10), Estado Sin caja
#   - Agente 2: Posición (9, 0), Estado Sin caja
#   - Agente 3: Posición (16, 9), Estado Con caja
#   - Agente 4: Posición (13, 14), Estado Sin caja
# Agente 0 colocó una caja en (6, 3)
# Agente 0 se movió a (7, 4)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (9, 1)
# Agente 3 colocó una caja en (16, 10)
# Agente 3 se movió a (17, 9)
# Agente 1 recogió una caja de (14, 10)
# Agente 1 se movió a (13, 9)
# Agente 4 recogió una caja de (13, 15)
# Agente 4 se movió a (14, 14)
# Paso 17:
#   - Agente 0: Posición (7, 4), Estado Sin caja
#   - Agente 1: Posición (13, 9), Estado Con caja
#   - Agente 2: Posición (9, 1), Estado Sin caja
#   - Agente 3: Posición (17, 9), Estado Sin caja
#   - Agente 4: Posición (14, 14), Estado Con caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 4)
# Agente 1 colocó una caja en (12, 9)
# Agente 1 se movió a (12, 9)
# Agente 2 recogió una caja de (10, 1)
# Agente 2 se movió a (10, 1)
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (14, 13)
# Agente 3 recogió una caja de (17, 8)
# Agente 3 se movió a (18, 9)
# Paso 18:
#   - Agente 0: Posición (6, 4), Estado Sin caja
#   - Agente 1: Posición (12, 9), Estado Sin caja
#   - Agente 2: Posición (10, 1), Estado Con caja
#   - Agente 3: Posición (18, 9), Estado Con caja
#   - Agente 4: Posición (14, 13), Estado Sin caja
# Agente 2 colocó una caja en (11, 1)
# Agente 2 se movió a (10, 2)
# Agente 3 colocó una caja en (18, 8)
# Agente 3 se movió a (17, 9)
# Agente 0 recogió una caja de (6, 3)
# Agente 0 se movió a (6, 5)
# Agente 4 recogió una caja de (14, 13)
# Agente 4 se movió a (15, 13)
# Agente 1 recogió una caja de (12, 9)
# Agente 1 se movió a (13, 9)
# Paso 19:
#   - Agente 0: Posición (6, 5), Estado Con caja
#   - Agente 1: Posición (13, 9), Estado Con caja
#   - Agente 2: Posición (10, 2), Estado Sin caja
#   - Agente 3: Posición (17, 9), Estado Sin caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (16, 9)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (10, 3)
# Agente 1 colocó una caja en (12, 9)
# Agente 1 se movió a (14, 9)
# Agente 0 colocó una caja en (6, 5)
# Agente 0 se movió a (6, 6)
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (14, 13)
# Paso 20:
#   - Agente 0: Posición (6, 6), Estado Sin caja
#   - Agente 1: Posición (14, 9), Estado Sin caja
#   - Agente 2: Posición (10, 3), Estado Sin caja
#   - Agente 3: Posición (16, 9), Estado Sin caja
#   - Agente 4: Posición (14, 13), Estado Sin caja
# Agente 0 recogió una caja de (6, 6)
# Agente 0 se movió a (7, 6)
# Agente 2 recogió una caja de (10, 4)
# Agente 2 se movió a (10, 2)
# Agente 1 recogió una caja de (14, 10)
# Agente 1 se movió a (14, 10)
# Agente 3 recogió una caja de (16, 10)
# Agente 3 se movió a (16, 8)
# Agente 4 recogió una caja de (14, 13)
# Agente 4 se movió a (15, 13)
# Paso 21:
#   - Agente 0: Posición (7, 6), Estado Con caja
#   - Agente 1: Posición (14, 10), Estado Con caja
#   - Agente 2: Posición (10, 2), Estado Con caja
#   - Agente 3: Posición (16, 8), Estado Con caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 2 colocó una caja en (9, 2)
# Agente 2 se movió a (10, 3)
# Agente 3 colocó una caja en (16, 7)
# Agente 3 se movió a (15, 8)
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (14, 13)
# Agente 0 colocó una caja en (6, 6)
# Agente 0 se movió a (8, 6)
# Agente 1 colocó una caja en (14, 10)
# Agente 1 se movió a (14, 9)
# Paso 22:
#   - Agente 0: Posición (8, 6), Estado Sin caja
#   - Agente 1: Posición (14, 9), Estado Sin caja
#   - Agente 2: Posición (10, 3), Estado Sin caja
#   - Agente 3: Posición (15, 8), Estado Sin caja
#   - Agente 4: Posición (14, 13), Estado Sin caja
# Agente 1 recogió una caja de (14, 10)
# Agente 1 se movió a (13, 9)
# Agente 0 recogió una caja de (8, 7)
# Agente 0 se movió a (8, 7)
# Agente 3 recogió una caja de (15, 7)
# Agente 3 se movió a (14, 8)
# Agente 4 recogió una caja de (14, 13)
# Agente 4 se movió a (15, 13)
# Agente 2 recogió una caja de (10, 4)
# Agente 2 se movió a (11, 3)
# Paso 23:
#   - Agente 0: Posición (8, 7), Estado Con caja
#   - Agente 1: Posición (13, 9), Estado Con caja
#   - Agente 2: Posición (11, 3), Estado Con caja
#   - Agente 3: Posición (14, 8), Estado Con caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 1 colocó una caja en (12, 9)
# Agente 1 se movió a (14, 9)
# Agente 3 colocó una caja en (13, 8)
# Agente 3 se movió a (15, 8)
# Agente 2 colocó una caja en (10, 3)
# Agente 2 se movió a (10, 3)
# Agente 0 colocó una caja en (8, 8)
# Agente 0 se movió a (9, 7)
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (16, 13)
# Paso 24:
#   - Agente 0: Posición (9, 7), Estado Sin caja
#   - Agente 1: Posición (14, 9), Estado Sin caja
#   - Agente 2: Posición (10, 3), Estado Sin caja
#   - Agente 3: Posición (15, 8), Estado Sin caja
#   - Agente 4: Posición (16, 13), Estado Sin caja
# Agente 0 recogió una caja de (9, 6)
# Agente 0 se movió a (9, 8)
# Agente 3 recogió una caja de (15, 7)
# Agente 3 se movió a (15, 7)
# Agente 2 recogió una caja de (10, 3)
# Agente 2 se movió a (10, 4)
# Agente 1 recogió una caja de (14, 10)
# Agente 1 se movió a (14, 10)
# Agente 4 recogió una caja de (16, 14)
# Agente 4 se movió a (15, 13)
# Paso 25:
#   - Agente 0: Posición (9, 8), Estado Con caja
#   - Agente 1: Posición (14, 10), Estado Con caja
#   - Agente 2: Posición (10, 4), Estado Con caja
#   - Agente 3: Posición (15, 7), Estado Con caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 3 colocó una caja en (16, 7)
# Agente 3 se movió a (14, 7)
# Agente 0 colocó una caja en (8, 8)
# Agente 0 se movió a (8, 8)
# Agente 4 colocó una caja en (14, 13)
# Agente 4 se movió a (15, 14)
# Agente 1 colocó una caja en (13, 10)
# Agente 1 se movió a (13, 10)
# Agente 2 colocó una caja en (9, 4)
# Agente 2 se movió a (10, 3)
# Paso 26:
#   - Agente 0: Posición (8, 8), Estado Sin caja
#   - Agente 1: Posición (13, 10), Estado Sin caja
#   - Agente 2: Posición (10, 3), Estado Sin caja
#   - Agente 3: Posición (14, 7), Estado Sin caja
#   - Agente 4: Posición (15, 14), Estado Sin caja
# Agente 4 recogió una caja de (16, 14)
# Agente 4 se movió a (15, 13)
# Agente 3 recogió una caja de (13, 7)
# Agente 3 se movió a (15, 7)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 7)
# Agente 1 recogió una caja de (13, 10)
# Agente 1 se movió a (14, 10)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (10, 4)
# Paso 27:
#   - Agente 0: Posición (8, 7), Estado Sin caja
#   - Agente 1: Posición (14, 10), Estado Con caja
#   - Agente 2: Posición (10, 4), Estado Sin caja
#   - Agente 3: Posición (15, 7), Estado Con caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 6)
# Agente 2 recogió una caja de (9, 4)
# Agente 2 se movió a (9, 4)
# Agente 1 colocó una caja en (13, 10)
# Agente 1 se movió a (15, 10)
# Agente 4 colocó una caja en (15, 12)
# Agente 4 se movió a (14, 13)
# Agente 3 colocó una caja en (16, 7)
# Agente 3 se movió a (15, 8)
# Paso 28:
#   - Agente 0: Posición (8, 6), Estado Sin caja
#   - Agente 1: Posición (15, 10), Estado Sin caja
#   - Agente 2: Posición (9, 4), Estado Con caja
#   - Agente 3: Posición (15, 8), Estado Sin caja
#   - Agente 4: Posición (14, 13), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 14)
# Agente 2 colocó una caja en (8, 4)
# Agente 2 se movió a (8, 4)
# Agente 1 recogió una caja de (16, 10)
# Agente 1 se movió a (14, 10)
# Agente 0 recogió una caja de (9, 6)
# Agente 0 se movió a (9, 6)
# Agente 3 recogió una caja de (15, 7)
# Agente 3 se movió a (16, 8)
# Paso 29:
#   - Agente 0: Posición (9, 6), Estado Con caja
#   - Agente 1: Posición (14, 10), Estado Con caja
#   - Agente 2: Posición (8, 4), Estado Sin caja
#   - Agente 3: Posición (16, 8), Estado Con caja
#   - Agente 4: Posición (14, 14), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (15, 14)
# Agente 1 colocó una caja en (13, 10)
# Agente 1 se movió a (13, 10)
# Agente 2 recogió una caja de (8, 4)
# Agente 2 se movió a (8, 5)
# Agente 3 colocó una caja en (16, 7)
# Agente 3 se movió a (16, 7)
# Agente 0 colocó una caja en (9, 6)
# Agente 0 se movió a (10, 6)
# Paso 30:
#   - Agente 0: Posición (10, 6), Estado Sin caja
#   - Agente 1: Posición (13, 10), Estado Sin caja
#   - Agente 2: Posición (8, 5), Estado Con caja
#   - Agente 3: Posición (16, 7), Estado Sin caja
#   - Agente 4: Posición (15, 14), Estado Sin caja
# Agente 0 recogió una caja de (9, 6)
# Agente 0 se movió a (9, 6)
# Agente 4 recogió una caja de (16, 14)
# Agente 4 se movió a (15, 13)
# Agente 2 colocó una caja en (7, 5)
# Agente 2 se movió a (9, 5)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (15, 7)
# Agente 1 recogió una caja de (13, 10)
# Agente 1 se movió a (13, 11)
# Paso 31:
#   - Agente 0: Posición (9, 6), Estado Con caja
#   - Agente 1: Posición (13, 11), Estado Con caja
#   - Agente 2: Posición (9, 5), Estado Sin caja
#   - Agente 3: Posición (15, 7), Estado Sin caja
#   - Agente 4: Posición (15, 13), Estado Con caja
# Agente 4 colocó una caja en (15, 12)
# Agente 4 se movió a (16, 13)
# Agente 0 colocó una caja en (9, 6)
# Agente 0 se movió a (8, 6)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (16, 7)
# Agente 1 colocó una caja en (13, 10)
# Agente 1 se movió a (14, 11)
# Agente 2 recogió una caja de (9, 6)
# Agente 2 se movió a (9, 6)
# Paso 32:
#   - Agente 0: Posición (8, 6), Estado Sin caja
#   - Agente 1: Posición (14, 11), Estado Sin caja
#   - Agente 2: Posición (9, 6), Estado Con caja
#   - Agente 3: Posición (16, 7), Estado Sin caja
#   - Agente 4: Posición (16, 13), Estado Sin caja
# Agente 4 recogió una caja de (16, 14)
# Agente 4 se movió a (17, 13)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (14, 10)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (16, 8)
# Agente 0 recogió una caja de (9, 6)
# Agente 0 se movió a (9, 6)
# Agente 2 colocó una caja en (8, 6)
# Agente 2 se movió a (10, 6)
# Paso 33:
#   - Agente 0: Posición (9, 6), Estado Con caja
#   - Agente 1: Posición (14, 10), Estado Sin caja
#   - Agente 2: Posición (10, 6), Estado Sin caja
#   - Agente 3: Posición (16, 8), Estado Sin caja
#   - Agente 4: Posición (17, 13), Estado Con caja
# Agente 4 colocó una caja en (16, 13)
# Agente 4 se movió a (17, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (10, 7)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (17, 8)
# Agente 0 colocó una caja en (8, 6)
# Agente 0 se movió a (9, 7)
# Agente 1 recogió una caja de (13, 10)
# Agente 1 se movió a (15, 10)
# Paso 34:
#   - Agente 0: Posición (9, 7), Estado Sin caja
#   - Agente 1: Posición (15, 10), Estado Con caja
#   - Agente 2: Posición (10, 7), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Sin caja
#   - Agente 4: Posición (17, 14), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (16, 14)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (9, 6)
# Agente 1 colocó una caja en (16, 10)
# Agente 1 se movió a (14, 10)
# Agente 3 recogió una caja de (18, 8)
# Agente 3 se movió a (16, 8)
# Agente 2 recogió una caja de (10, 8)
# Agente 2 se movió a (10, 6)
# Paso 35:
#   - Agente 0: Posición (9, 6), Estado Sin caja
#   - Agente 1: Posición (14, 10), Estado Sin caja
#   - Agente 2: Posición (10, 6), Estado Con caja
#   - Agente 3: Posición (16, 8), Estado Con caja
#   - Agente 4: Posición (16, 14), Estado Sin caja
# Agente 2 colocó una caja en (9, 6)
# Agente 2 se movió a (10, 7)
# Agente 1 recogió una caja de (13, 10)
# Agente 1 se movió a (15, 10)
# Agente 3 colocó una caja en (15, 8)
# Agente 3 se movió a (15, 8)
# Agente 0 recogió una caja de (9, 6)
# Agente 0 se movió a (8, 6)
# Agente 4 recogió una caja de (16, 13)
# Agente 4 se movió a (15, 14)
# Paso 36:
#   - Agente 0: Posición (8, 6), Estado Con caja
#   - Agente 1: Posición (15, 10), Estado Con caja
#   - Agente 2: Posición (10, 7), Estado Sin caja
#   - Agente 3: Posición (15, 8), Estado Sin caja
#   - Agente 4: Posición (15, 14), Estado Con caja
# Agente 2 recogió una caja de (11, 7)
# Agente 2 se movió a (10, 8)
# Agente 3 recogió una caja de (15, 8)
# Agente 3 se movió a (15, 9)
# Agente 1 colocó una caja en (16, 10)
# Agente 1 se movió a (15, 11)
# Agente 0 colocó una caja en (8, 6)
# Agente 0 se movió a (7, 6)
# Agente 4 colocó una caja en (15, 13)
# Agente 4 se movió a (14, 14)
# Paso 37:
#   - Agente 0: Posición (7, 6), Estado Sin caja
#   - Agente 1: Posición (15, 11), Estado Sin caja
#   - Agente 2: Posición (10, 8), Estado Con caja
#   - Agente 3: Posición (15, 9), Estado Con caja
#   - Agente 4: Posición (14, 14), Estado Sin caja
# Agente 1 recogió una caja de (15, 12)
# Agente 1 se movió a (15, 12)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 15)
# Agente 3 colocó una caja en (14, 9)
# Agente 3 se movió a (16, 9)
# Agente 2 colocó una caja en (10, 9)
# Agente 2 se movió a (9, 8)
# Agente 0 recogió una caja de (7, 5)
# Agente 0 se movió a (6, 6)
# Paso 38:
#   - Agente 0: Posición (6, 6), Estado Con caja
#   - Agente 1: Posición (15, 12), Estado Con caja
#   - Agente 2: Posición (9, 8), Estado Sin caja
#   - Agente 3: Posición (16, 9), Estado Sin caja
#   - Agente 4: Posición (14, 15), Estado Sin caja
# Agente 0 colocó una caja en (6, 5)
# Agente 0 se movió a (7, 6)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 15)
# Agente 2 recogió una caja de (9, 9)
# Agente 2 se movió a (8, 8)
# Agente 3 recogió una caja de (16, 10)
# Agente 3 se movió a (16, 8)
# Agente 1 colocó una caja en (15, 12)
# Agente 1 se movió a (14, 12)
# Paso 39:
#   - Agente 0: Posición (7, 6), Estado Sin caja
#   - Agente 1: Posición (14, 12), Estado Sin caja
#   - Agente 2: Posición (8, 8), Estado Con caja
#   - Agente 3: Posición (16, 8), Estado Con caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 14)
# Agente 1 recogió una caja de (15, 12)
# Agente 1 se movió a (14, 13)
# Agente 0 recogió una caja de (6, 6)
# Agente 0 se movió a (8, 6)
# Agente 3 colocó una caja en (15, 8)
# Agente 3 se movió a (16, 7)
# Agente 2 colocó una caja en (7, 8)
# Agente 2 se movió a (7, 8)
# Paso 40:
#   - Agente 0: Posición (8, 6), Estado Con caja
#   - Agente 1: Posición (14, 13), Estado Con caja
#   - Agente 2: Posición (7, 8), Estado Sin caja
#   - Agente 3: Posición (16, 7), Estado Sin caja
#   - Agente 4: Posición (13, 14), Estado Sin caja
# Agente 0 colocó una caja en (8, 6)
# Agente 0 se movió a (9, 6)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (17, 7)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 15)
# Agente 1 colocó una caja en (15, 13)
# Agente 1 se movió a (15, 13)
# Agente 2 recogió una caja de (7, 8)
# Agente 2 se movió a (7, 7)
# Paso 41:
#   - Agente 0: Posición (9, 6), Estado Sin caja
#   - Agente 1: Posición (15, 13), Estado Sin caja
#   - Agente 2: Posición (7, 7), Estado Con caja
#   - Agente 3: Posición (17, 7), Estado Sin caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 0 recogió una caja de (8, 6)
# Agente 0 se movió a (9, 5)
# Agente 2 colocó una caja en (6, 7)
# Agente 2 se movió a (8, 7)
# Agente 1 recogió una caja de (15, 12)
# Agente 1 se movió a (15, 12)
# Agente 3 recogió una caja de (18, 7)
# Agente 3 se movió a (17, 8)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 14)
# Paso 42:
#   - Agente 0: Posición (9, 5), Estado Con caja
#   - Agente 1: Posición (15, 12), Estado Con caja
#   - Agente 2: Posición (8, 7), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Con caja
#   - Agente 4: Posición (13, 14), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 15)
# Agente 1 colocó una caja en (15, 13)
# Agente 1 se movió a (15, 13)
# Agente 3 colocó una caja en (16, 8)
# Agente 3 se movió a (18, 8)
# Agente 0 colocó una caja en (8, 5)
# Agente 0 se movió a (8, 5)
# Agente 2 recogió una caja de (8, 6)
# Agente 2 se movió a (7, 7)
# Paso 43:
#   - Agente 0: Posición (8, 5), Estado Sin caja
#   - Agente 1: Posición (15, 13), Estado Sin caja
#   - Agente 2: Posición (7, 7), Estado Con caja
#   - Agente 3: Posición (18, 8), Estado Sin caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 3 recogió una caja de (18, 7)
# Agente 3 se movió a (19, 8)
# Agente 2 colocó una caja en (6, 7)
# Agente 2 se movió a (8, 7)
# Agente 1 recogió una caja de (15, 13)
# Agente 1 se movió a (15, 14)
# Agente 0 recogió una caja de (8, 5)
# Agente 0 se movió a (7, 5)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 15)
# Paso 44:
#   - Agente 0: Posición (7, 5), Estado Con caja
#   - Agente 1: Posición (15, 14), Estado Con caja
#   - Agente 2: Posición (8, 7), Estado Sin caja
#   - Agente 3: Posición (19, 8), Estado Con caja
#   - Agente 4: Posición (14, 15), Estado Sin caja
# Agente 0 colocó una caja en (6, 5)
# Agente 0 se movió a (7, 6)
# Agente 1 colocó una caja en (15, 13)
# Agente 1 se movió a (15, 15)
# Agente 2 recogió una caja de (8, 6)
# Agente 2 se movió a (7, 7)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 15)
# Agente 3 colocó una caja en (18, 8)
# Agente 3 se movió a (18, 8)
# Paso 45:
#   - Agente 0: Posición (7, 6), Estado Sin caja
#   - Agente 1: Posición (15, 15), Estado Sin caja
#   - Agente 2: Posición (7, 7), Estado Con caja
#   - Agente 3: Posición (18, 8), Estado Sin caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 2 colocó una caja en (6, 7)
# Agente 2 se movió a (6, 7)
# Agente 0 recogió una caja de (6, 6)
# Agente 0 se movió a (8, 6)
# Agente 3 recogió una caja de (18, 7)
# Agente 3 se movió a (17, 8)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 14)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (15, 14)
# Paso 46:
#   - Agente 0: Posición (8, 6), Estado Con caja
#   - Agente 1: Posición (15, 14), Estado Sin caja
#   - Agente 2: Posición (6, 7), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Con caja
#   - Agente 4: Posición (13, 14), Estado Sin caja
# Agente 1 recogió una caja de (15, 13)
# Agente 1 se movió a (16, 14)
# Agente 3 colocó una caja en (16, 8)
# Agente 3 se movió a (17, 7)
# Agente 2 recogió una caja de (6, 7)
# Agente 2 se movió a (6, 8)
# Agente 0 colocó una caja en (8, 6)
# Agente 0 se movió a (8, 5)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 14)
# Paso 47:
#   - Agente 0: Posición (8, 5), Estado Sin caja
#   - Agente 1: Posición (16, 14), Estado Con caja
#   - Agente 2: Posición (6, 8), Estado Con caja
#   - Agente 3: Posición (17, 7), Estado Sin caja
#   - Agente 4: Posición (12, 14), Estado Sin caja
# Agente 0 recogió una caja de (8, 6)
# Agente 0 se movió a (9, 5)
# Agente 1 colocó una caja en (15, 14)
# Agente 1 se movió a (16, 13)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 13)
# Agente 2 colocó una caja en (6, 7)
# Agente 2 se movió a (6, 9)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (18, 7)
# Paso 48:
#   - Agente 0: Posición (9, 5), Estado Con caja
#   - Agente 1: Posición (16, 13), Estado Sin caja
#   - Agente 2: Posición (6, 9), Estado Sin caja
#   - Agente 3: Posición (18, 7), Estado Sin caja
#   - Agente 4: Posición (12, 13), Estado Sin caja
# Agente 2 recogió una caja de (6, 9)
# Agente 2 se movió a (5, 9)
# Agente 3 recogió una caja de (18, 8)
# Agente 3 se movió a (18, 6)
# Agente 1 recogió una caja de (15, 13)
# Agente 1 se movió a (17, 13)
# Agente 0 colocó una caja en (8, 5)
# Agente 0 se movió a (9, 6)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (11, 13)
# Paso 49:
#   - Agente 0: Posición (9, 6), Estado Sin caja
#   - Agente 1: Posición (17, 13), Estado Con caja
#   - Agente 2: Posición (5, 9), Estado Con caja
#   - Agente 3: Posición (18, 6), Estado Con caja
#   - Agente 4: Posición (11, 13), Estado Sin caja
# Agente 4 recogió una caja de (10, 13)
# Agente 4 se movió a (12, 13)
# Agente 3 colocó una caja en (17, 6)
# Agente 3 se movió a (17, 6)
# Agente 2 colocó una caja en (5, 10)
# Agente 2 se movió a (5, 8)
# Agente 1 colocó una caja en (16, 13)
# Agente 1 se movió a (16, 13)
# Agente 0 recogió una caja de (8, 6)
# Agente 0 se movió a (9, 5)
# Paso 50:
#   - Agente 0: Posición (9, 5), Estado Con caja
#   - Agente 1: Posición (16, 13), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (17, 6), Estado Sin caja
#   - Agente 4: Posición (12, 13), Estado Con caja
# Agente 0 colocó una caja en (8, 5)
# Agente 0 se movió a (10, 5)
# Agente 4 colocó una caja en (11, 13)
# Agente 4 se movió a (11, 13)
# Agente 3 recogió una caja de (17, 6)
# Agente 3 se movió a (17, 7)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (4, 8)
# Agente 1 recogió una caja de (15, 13)
# Agente 1 se movió a (17, 13)
# Paso 51:
#   - Agente 0: Posición (10, 5), Estado Sin caja
#   - Agente 1: Posición (17, 13), Estado Con caja
#   - Agente 2: Posición (4, 8), Estado Sin caja
#   - Agente 3: Posición (17, 7), Estado Con caja
#   - Agente 4: Posición (11, 13), Estado Sin caja
# Agente 0 recogió una caja de (11, 5)
# Agente 0 se movió a (11, 5)
# Agente 2 recogió una caja de (4, 9)
# Agente 2 se movió a (3, 8)
# Agente 1 colocó una caja en (16, 13)
# Agente 1 se movió a (17, 14)
# Agente 4 recogió una caja de (11, 13)
# Agente 4 se movió a (11, 12)
# Agente 3 colocó una caja en (17, 6)
# Agente 3 se movió a (16, 7)
# Paso 52:
#   - Agente 0: Posición (11, 5), Estado Con caja
#   - Agente 1: Posición (17, 14), Estado Sin caja
#   - Agente 2: Posición (3, 8), Estado Con caja
#   - Agente 3: Posición (16, 7), Estado Sin caja
#   - Agente 4: Posición (11, 12), Estado Con caja
# Agente 3 recogió una caja de (16, 8)
# Agente 3 se movió a (16, 8)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (16, 14)
# Agente 2 colocó una caja en (2, 8)
# Agente 2 se movió a (4, 8)
# Agente 4 colocó una caja en (10, 12)
# Agente 4 se movió a (12, 12)
# Agente 0 colocó una caja en (11, 5)
# Agente 0 se movió a (11, 4)
# Paso 53:
#   - Agente 0: Posición (11, 4), Estado Sin caja
#   - Agente 1: Posición (16, 14), Estado Sin caja
#   - Agente 2: Posición (4, 8), Estado Sin caja
#   - Agente 3: Posición (16, 8), Estado Con caja
#   - Agente 4: Posición (12, 12), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 13)
# Agente 3 colocó una caja en (15, 8)
# Agente 3 se movió a (17, 8)
# Agente 0 recogió una caja de (11, 5)
# Agente 0 se movió a (11, 3)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 8)
# Agente 1 recogió una caja de (15, 14)
# Agente 1 se movió a (16, 15)
# Paso 54:
#   - Agente 0: Posición (11, 3), Estado Con caja
#   - Agente 1: Posición (16, 15), Estado Con caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Sin caja
#   - Agente 4: Posición (12, 13), Estado Sin caja
# Agente 1 colocó una caja en (16, 14)
# Agente 1 se movió a (17, 15)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (4, 8)
# Agente 0 colocó una caja en (10, 3)
# Agente 0 se movió a (12, 3)
# Agente 3 recogió una caja de (16, 8)
# Agente 3 se movió a (17, 9)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 14)
# Paso 55:
#   - Agente 0: Posición (12, 3), Estado Sin caja
#   - Agente 1: Posición (17, 15), Estado Sin caja
#   - Agente 2: Posición (4, 8), Estado Sin caja
#   - Agente 3: Posición (17, 9), Estado Con caja
#   - Agente 4: Posición (12, 14), Estado Sin caja
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 8)
# Agente 0 recogió una caja de (12, 2)
# Agente 0 se movió a (12, 2)
# Agente 3 colocó una caja en (16, 9)
# Agente 3 se movió a (17, 8)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (11, 14)
# Agente 1 recogió una caja de (18, 15)
# Agente 1 se movió a (18, 15)
# Paso 56:
#   - Agente 0: Posición (12, 2), Estado Con caja
#   - Agente 1: Posición (18, 15), Estado Con caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Sin caja
#   - Agente 4: Posición (11, 14), Estado Sin caja
# Agente 4 recogió una caja de (11, 15)
# Agente 4 se movió a (11, 15)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (17, 9)
# Agente 1 colocó una caja en (17, 15)
# Agente 1 se movió a (19, 15)
# Agente 0 colocó una caja en (12, 2)
# Agente 0 se movió a (13, 2)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (4, 8)
# Paso 57:
#   - Agente 0: Posición (13, 2), Estado Sin caja
#   - Agente 1: Posición (19, 15), Estado Sin caja
#   - Agente 2: Posición (4, 8), Estado Sin caja
#   - Agente 3: Posición (17, 9), Estado Sin caja
#   - Agente 4: Posición (11, 15), Estado Con caja
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 8)
# Agente 4 colocó una caja en (11, 15)
# Agente 4 se movió a (11, 14)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (18, 15)
# Agente 0 recogió una caja de (12, 2)
# Agente 0 se movió a (13, 1)
# Agente 3 recogió una caja de (16, 9)
# Agente 3 se movió a (17, 10)
# Paso 58:
#   - Agente 0: Posición (13, 1), Estado Con caja
#   - Agente 1: Posición (18, 15), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (17, 10), Estado Con caja
#   - Agente 4: Posición (11, 14), Estado Sin caja
# Agente 0 colocó una caja en (13, 1)
# Agente 0 se movió a (13, 2)
# Agente 1 recogió una caja de (17, 15)
# Agente 1 se movió a (18, 14)
# Agente 4 recogió una caja de (11, 15)
# Agente 4 se movió a (12, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 9)
# Agente 3 colocó una caja en (16, 10)
# Agente 3 se movió a (16, 10)
# Paso 59:
#   - Agente 0: Posición (13, 2), Estado Sin caja
#   - Agente 1: Posición (18, 14), Estado Con caja
#   - Agente 2: Posición (5, 9), Estado Sin caja
#   - Agente 3: Posición (16, 10), Estado Sin caja
#   - Agente 4: Posición (12, 14), Estado Con caja
# Agente 0 recogió una caja de (12, 2)
# Agente 0 se movió a (12, 2)
# Agente 3 recogió una caja de (16, 10)
# Agente 3 se movió a (16, 9)
# Agente 1 colocó una caja en (17, 14)
# Agente 1 se movió a (18, 15)
# Agente 2 recogió una caja de (6, 9)
# Agente 2 se movió a (5, 8)
# Agente 4 colocó una caja en (11, 14)
# Agente 4 se movió a (12, 13)
# Paso 60:
#   - Agente 0: Posición (12, 2), Estado Con caja
#   - Agente 1: Posición (18, 15), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Con caja
#   - Agente 3: Posición (16, 9), Estado Con caja
#   - Agente 4: Posición (12, 13), Estado Sin caja
# Agente 3 colocó una caja en (16, 10)
# Agente 3 se movió a (16, 10)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 14)
# Agente 0 colocó una caja en (11, 2)
# Agente 0 se movió a (13, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (18, 14)
# Agente 2 colocó una caja en (4, 8)
# Agente 2 se movió a (5, 7)
# Paso 61:
#   - Agente 0: Posición (13, 2), Estado Sin caja
#   - Agente 1: Posición (18, 14), Estado Sin caja
#   - Agente 2: Posición (5, 7), Estado Sin caja
#   - Agente 3: Posición (16, 10), Estado Sin caja
#   - Agente 4: Posición (12, 14), Estado Sin caja
# Agente 2 recogió una caja de (6, 7)
# Agente 2 se movió a (4, 7)
# Agente 0 recogió una caja de (13, 1)
# Agente 0 se movió a (13, 1)
# Agente 4 recogió una caja de (11, 14)
# Agente 4 se movió a (13, 14)
# Agente 3 recogió una caja de (16, 10)
# Agente 3 se movió a (16, 9)
# Agente 1 recogió una caja de (17, 14)
# Agente 1 se movió a (17, 14)
# Paso 62:
#   - Agente 0: Posición (13, 1), Estado Con caja
#   - Agente 1: Posición (17, 14), Estado Con caja
#   - Agente 2: Posición (4, 7), Estado Con caja
#   - Agente 3: Posición (16, 9), Estado Con caja
#   - Agente 4: Posición (13, 14), Estado Con caja
# Agente 1 colocó una caja en (16, 14)
# Agente 1 se movió a (18, 14)
# Agente 4 colocó una caja en (12, 14)
# Agente 4 se movió a (13, 13)
# Agente 3 colocó una caja en (16, 10)
# Agente 3 se movió a (17, 9)
# Agente 0 colocó una caja en (13, 1)
# Agente 0 se movió a (13, 0)
# Agente 2 colocó una caja en (4, 8)
# Agente 2 se movió a (3, 7)
# Paso 63:
#   - Agente 0: Posición (13, 0), Estado Sin caja
#   - Agente 1: Posición (18, 14), Estado Sin caja
#   - Agente 2: Posición (3, 7), Estado Sin caja
#   - Agente 3: Posición (17, 9), Estado Sin caja
#   - Agente 4: Posición (13, 13), Estado Sin caja
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (4, 7)
# Agente 0 recogió una caja de (14, 0)
# Agente 0 se movió a (14, 0)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (17, 14)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (17, 8)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 14)
# Paso 64:
#   - Agente 0: Posición (14, 0), Estado Con caja
#   - Agente 1: Posición (17, 14), Estado Sin caja
#   - Agente 2: Posición (4, 7), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Sin caja
#   - Agente 4: Posición (13, 14), Estado Sin caja
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (17, 9)
# Agente 4 recogió una caja de (12, 14)
# Agente 4 se movió a (12, 14)
# Agente 0 colocó una caja en (13, 0)
# Agente 0 se movió a (14, 1)
# Agente 2 recogió una caja de (4, 8)
# Agente 2 se movió a (4, 8)
# Agente 1 recogió una caja de (16, 14)
# Agente 1 se movió a (17, 13)
# Paso 65:
#   - Agente 0: Posición (14, 1), Estado Sin caja
#   - Agente 1: Posición (17, 13), Estado Con caja
#   - Agente 2: Posición (4, 8), Estado Con caja
#   - Agente 3: Posición (17, 9), Estado Sin caja
#   - Agente 4: Posición (12, 14), Estado Con caja
# Agente 0 recogió una caja de (13, 1)
# Agente 0 se movió a (13, 1)
# Agente 1 colocó una caja en (16, 13)
# Agente 1 se movió a (18, 13)
# Agente 2 colocó una caja en (4, 8)
# Agente 2 se movió a (5, 8)
# Agente 4 colocó una caja en (11, 14)
# Agente 4 se movió a (12, 15)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (17, 10)
# Paso 66:
#   - Agente 0: Posición (13, 1), Estado Con caja
#   - Agente 1: Posición (18, 13), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (17, 10), Estado Sin caja
#   - Agente 4: Posición (12, 15), Estado Sin caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (17, 13)
# Agente 0 colocó una caja en (13, 1)
# Agente 0 se movió a (13, 2)
# Agente 3 recogió una caja de (16, 10)
# Agente 3 se movió a (17, 9)
# Agente 4 recogió una caja de (11, 15)
# Agente 4 se movió a (13, 15)
# Agente 2 recogió una caja de (4, 8)
# Agente 2 se movió a (5, 9)
# Paso 67:
#   - Agente 0: Posición (13, 2), Estado Sin caja
#   - Agente 1: Posición (17, 13), Estado Sin caja
#   - Agente 2: Posición (5, 9), Estado Con caja
#   - Agente 3: Posición (17, 9), Estado Con caja
#   - Agente 4: Posición (13, 15), Estado Con caja
# Agente 2 colocó una caja en (4, 9)
# Agente 2 se movió a (4, 9)
# Agente 3 colocó una caja en (16, 9)
# Agente 3 se movió a (17, 8)
# Agente 1 recogió una caja de (16, 13)
# Agente 1 se movió a (18, 13)
# Agente 0 recogió una caja de (13, 1)
# Agente 0 se movió a (13, 1)
# Agente 4 colocó una caja en (12, 15)
# Agente 4 se movió a (13, 16)
# Paso 68:
#   - Agente 0: Posición (13, 1), Estado Con caja
#   - Agente 1: Posición (18, 13), Estado Con caja
#   - Agente 2: Posición (4, 9), Estado Sin caja
#   - Agente 3: Posición (17, 8), Estado Sin caja
#   - Agente 4: Posición (13, 16), Estado Sin caja
# Agente 1 colocó una caja en (17, 13)
# Agente 1 se movió a (19, 13)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 16)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (16, 8)
# Agente 0 colocó una caja en (13, 1)
# Agente 0 se movió a (14, 1)
# Agente 2 recogió una caja de (4, 8)
# Agente 2 se movió a (4, 8)
# Paso 69:
#   - Agente 0: Posición (14, 1), Estado Sin caja
#   - Agente 1: Posición (19, 13), Estado Sin caja
#   - Agente 2: Posición (4, 8), Estado Con caja
#   - Agente 3: Posición (16, 8), Estado Sin caja
#   - Agente 4: Posición (12, 16), Estado Sin caja
# Agente 4 recogió una caja de (12, 15)
# Agente 4 se movió a (12, 15)
# Agente 3 recogió una caja de (16, 9)
# Agente 3 se movió a (15, 8)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (19, 12)
# Agente 2 colocó una caja en (4, 9)
# Agente 2 se movió a (5, 8)
# Agente 0 recogió una caja de (13, 1)
# Agente 0 se movió a (14, 0)
# Paso 70:
#   - Agente 0: Posición (14, 0), Estado Con caja
#   - Agente 1: Posición (19, 12), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (15, 8), Estado Con caja
#   - Agente 4: Posición (12, 15), Estado Con caja
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 7)
# Agente 0 colocó una caja en (13, 0)
# Agente 0 se movió a (13, 0)
# Agente 3 colocó una caja en (15, 8)
# Agente 3 se movió a (14, 8)
# Agente 4 colocó una caja en (11, 15)
# Agente 4 se movió a (13, 15)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (19, 13)
# Paso 71:
#   - Agente 0: Posición (13, 0), Estado Sin caja
#   - Agente 1: Posición (19, 13), Estado Sin caja
#   - Agente 2: Posición (5, 7), Estado Sin caja
#   - Agente 3: Posición (14, 8), Estado Sin caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 3 recogió una caja de (13, 8)
# Agente 3 se movió a (14, 9)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (18, 13)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 15)
# Agente 0 recogió una caja de (13, 0)
# Agente 0 se movió a (12, 0)
# Agente 2 recogió una caja de (6, 7)
# Agente 2 se movió a (5, 8)
# Paso 72:
#   - Agente 0: Posición (12, 0), Estado Con caja
#   - Agente 1: Posición (18, 13), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Con caja
#   - Agente 3: Posición (14, 9), Estado Con caja
#   - Agente 4: Posición (12, 15), Estado Sin caja
# Agente 1 recogió una caja de (17, 13)
# Agente 1 se movió a (18, 12)
# Agente 4 recogió una caja de (11, 15)
# Agente 4 se movió a (12, 14)
# Agente 0 colocó una caja en (13, 0)
# Agente 0 se movió a (11, 0)
# Agente 3 colocó una caja en (14, 9)
# Agente 3 se movió a (14, 8)
# Agente 2 colocó una caja en (4, 8)
# Agente 2 se movió a (4, 8)
# Paso 73:
#   - Agente 0: Posición (11, 0), Estado Sin caja
#   - Agente 1: Posición (18, 12), Estado Con caja
#   - Agente 2: Posición (4, 8), Estado Sin caja
#   - Agente 3: Posición (14, 8), Estado Sin caja
#   - Agente 4: Posición (12, 14), Estado Con caja
# Agente 0 recogió una caja de (11, 1)
# Agente 0 se movió a (12, 0)
# Agente 1 colocó una caja en (17, 12)
# Agente 1 se movió a (18, 13)
# Agente 3 recogió una caja de (14, 9)
# Agente 3 se movió a (14, 9)
# Agente 4 colocó una caja en (11, 14)
# Agente 4 se movió a (13, 14)
# Agente 2 recogió una caja de (4, 8)
# Agente 2 se movió a (4, 9)
# Paso 74:
#   - Agente 0: Posición (12, 0), Estado Con caja
#   - Agente 1: Posición (18, 13), Estado Sin caja
#   - Agente 2: Posición (4, 9), Estado Con caja
#   - Agente 3: Posición (14, 9), Estado Con caja
#   - Agente 4: Posición (13, 14), Estado Sin caja
# Agente 2 colocó una caja en (4, 9)
# Agente 2 se movió a (4, 10)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (19, 13)
# Agente 3 colocó una caja en (14, 9)
# Agente 3 se movió a (14, 8)
# Agente 0 colocó una caja en (13, 0)
# Agente 0 se movió a (13, 0)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 13)
# Paso 75:
#   - Agente 0: Posición (13, 0), Estado Sin caja
#   - Agente 1: Posición (19, 13), Estado Sin caja
#   - Agente 2: Posición (4, 10), Estado Sin caja
#   - Agente 3: Posición (14, 8), Estado Sin caja
#   - Agente 4: Posición (13, 13), Estado Sin caja
# Agente 3 recogió una caja de (14, 9)
# Agente 3 se movió a (15, 8)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (19, 14)
# Agente 2 recogió una caja de (4, 9)
# Agente 2 se movió a (5, 10)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 13)
# Agente 0 recogió una caja de (13, 1)
# Agente 0 se movió a (12, 0)
# Paso 76:
#   - Agente 0: Posición (12, 0), Estado Con caja
#   - Agente 1: Posición (19, 14), Estado Sin caja
#   - Agente 2: Posición (5, 10), Estado Con caja
#   - Agente 3: Posición (15, 8), Estado Con caja
#   - Agente 4: Posición (14, 13), Estado Sin caja
# Agente 2 colocó una caja en (4, 10)
# Agente 2 se movió a (5, 9)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 12)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (19, 13)
# Agente 0 colocó una caja en (13, 0)
# Agente 0 se movió a (12, 1)
# Agente 3 colocó una caja en (15, 8)
# Agente 3 se movió a (15, 7)
# Paso 77:
#   - Agente 0: Posición (12, 1), Estado Sin caja
#   - Agente 1: Posición (19, 13), Estado Sin caja
#   - Agente 2: Posición (5, 9), Estado Sin caja
#   - Agente 3: Posición (15, 7), Estado Sin caja
#   - Agente 4: Posición (14, 12), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 13)
# Agente 3 recogió una caja de (15, 8)
# Agente 3 se movió a (15, 6)
# Agente 2 recogió una caja de (4, 9)
# Agente 2 se movió a (5, 10)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (18, 13)
# Agente 0 recogió una caja de (13, 1)
# Agente 0 se movió a (12, 2)
# Paso 78:
#   - Agente 0: Posición (12, 2), Estado Con caja
#   - Agente 1: Posición (18, 13), Estado Sin caja
#   - Agente 2: Posición (5, 10), Estado Con caja
#   - Agente 3: Posición (15, 6), Estado Con caja
#   - Agente 4: Posición (14, 13), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 14)
# Agente 2 colocó una caja en (4, 10)
# Agente 2 se movió a (5, 11)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (18, 12)
# Agente 0 colocó una caja en (11, 2)
# Agente 0 se movió a (13, 2)
# Agente 3 colocó una caja en (14, 6)
# Agente 3 se movió a (14, 6)
# Paso 79:
#   - Agente 0: Posición (13, 2), Estado Sin caja
#   - Agente 1: Posición (18, 12), Estado Sin caja
#   - Agente 2: Posición (5, 11), Estado Sin caja
#   - Agente 3: Posición (14, 6), Estado Sin caja
#   - Agente 4: Posición (14, 14), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (13, 1)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (14, 15)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 10)
# Agente 1 recogió una caja de (17, 12)
# Agente 1 se movió a (18, 13)
# Agente 3 recogió una caja de (14, 6)
# Agente 3 se movió a (15, 6)
# Paso 80:
#   - Agente 0: Posición (13, 1), Estado Sin caja
#   - Agente 1: Posición (18, 13), Estado Con caja
#   - Agente 2: Posición (5, 10), Estado Sin caja
#   - Agente 3: Posición (15, 6), Estado Con caja
#   - Agente 4: Posición (14, 15), Estado Sin caja
# Agente 2 recogió una caja de (4, 10)
# Agente 2 se movió a (4, 10)
# Agente 1 colocó una caja en (17, 13)
# Agente 1 se movió a (17, 13)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (13, 15)
# Agente 3 colocó una caja en (14, 6)
# Agente 3 se movió a (15, 7)
# Agente 0 recogió una caja de (13, 0)
# Agente 0 se movió a (14, 1)
# Paso 81:
#   - Agente 0: Posición (14, 1), Estado Con caja
#   - Agente 1: Posición (17, 13), Estado Sin caja
#   - Agente 2: Posición (4, 10), Estado Con caja
#   - Agente 3: Posición (15, 7), Estado Sin caja
#   - Agente 4: Posición (13, 15), Estado Sin caja
# Agente 0 colocó una caja en (13, 1)
# Agente 0 se movió a (14, 0)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 15)
# Agente 3 recogió una caja de (15, 8)
# Agente 3 se movió a (15, 8)
# Agente 1 recogió una caja de (17, 13)
# Agente 1 se movió a (17, 14)
# Agente 2 colocó una caja en (4, 9)
# Agente 2 se movió a (5, 10)
# Paso 82:
#   - Agente 0: Posición (14, 0), Estado Sin caja
#   - Agente 1: Posición (17, 14), Estado Con caja
#   - Agente 2: Posición (5, 10), Estado Sin caja
#   - Agente 3: Posición (15, 8), Estado Con caja
#   - Agente 4: Posición (12, 15), Estado Sin caja
# Agente 3 colocó una caja en (15, 8)
# Agente 3 se movió a (15, 9)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (12, 16)
# Agente 0 recogió una caja de (13, 0)
# Agente 0 se movió a (14, 1)
# Agente 1 colocó una caja en (16, 14)
# Agente 1 se movió a (17, 15)
# Agente 2 recogió una caja de (4, 10)
# Agente 2 se movió a (5, 9)
# Paso 83:
#   - Agente 0: Posición (14, 1), Estado Con caja
#   - Agente 1: Posición (17, 15), Estado Sin caja
#   - Agente 2: Posición (5, 9), Estado Con caja
#   - Agente 3: Posición (15, 9), Estado Sin caja
#   - Agente 4: Posición (12, 16), Estado Sin caja
# Agente 0 colocó una caja en (13, 1)
# Agente 0 se movió a (14, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (18, 15)
# Agente 3 recogió una caja de (14, 9)
# Agente 3 se movió a (14, 9)
# ...
# Agente 2 se movió a (4, 4)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 13)
# Paso 3295:
#   - Agente 0: Posición (8, 13), Estado Sin caja
#   - Agente 1: Posición (10, 4), Estado Sin caja
#   - Agente 2: Posición (4, 4), Estado Sin caja
#   - Agente 3: Posición (10, 2), Estado Sin caja
#   - Agente 4: Posición (1, 5), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (2, 5)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (11, 2)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (4, 5)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 4)
# Paso 3296:
#   - Agente 0: Posición (8, 14), Estado Sin caja
#   - Agente 1: Posición (11, 4), Estado Sin caja
#   - Agente 2: Posición (4, 5), Estado Sin caja
#   - Agente 3: Posición (11, 2), Estado Sin caja
#   - Agente 4: Posición (2, 5), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 14)
# Agente 4 recogió una caja de (2, 4)
# Agente 4 se movió a (2, 4)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (12, 4)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 5)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (11, 1)
# Paso 3297:
#   - Agente 0: Posición (7, 14), Estado Sin caja
#   - Agente 1: Posición (12, 4), Estado Sin caja
#   - Agente 2: Posición (5, 5), Estado Sin caja
#   - Agente 3: Posición (11, 1), Estado Sin caja
#   - Agente 4: Posición (2, 4), Estado Con caja
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (11, 0)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (8, 14)
# Agente 4 colocó una caja en (2, 4)
# Agente 4 se movió a (2, 3)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 4)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (4, 5)
# Paso 3298:
#   - Agente 0: Posición (8, 14), Estado Sin caja
#   - Agente 1: Posición (11, 4), Estado Sin caja
#   - Agente 2: Posición (4, 5), Estado Sin caja
#   - Agente 3: Posición (11, 0), Estado Sin caja
#   - Agente 4: Posición (2, 3), Estado Sin caja
# Agente 4 recogió una caja de (2, 4)
# Agente 4 se movió a (2, 2)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (10, 0)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 5)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 5)
# Paso 3299:
#   - Agente 0: Posición (7, 14), Estado Sin caja
#   - Agente 1: Posición (11, 5), Estado Sin caja
#   - Agente 2: Posición (5, 5), Estado Sin caja
#   - Agente 3: Posición (10, 0), Estado Sin caja
#   - Agente 4: Posición (2, 2), Estado Con caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 4)
# Agente 4 colocó una caja en (1, 2)
# Agente 4 se movió a (2, 3)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 4)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 14)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (11, 0)
# Paso 3300:
#   - Agente 0: Posición (6, 14), Estado Sin caja
#   - Agente 1: Posición (11, 4), Estado Sin caja
#   - Agente 2: Posición (5, 4), Estado Sin caja
#   - Agente 3: Posición (11, 0), Estado Sin caja
#   - Agente 4: Posición (2, 3), Estado Sin caja
# Agente 4 recogió una caja de (2, 4)
# Agente 4 se movió a (3, 3)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (6, 4)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (10, 0)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 3)
# Paso 3301:
#   - Agente 0: Posición (7, 14), Estado Sin caja
#   - Agente 1: Posición (11, 3), Estado Sin caja
#   - Agente 2: Posición (6, 4), Estado Sin caja
#   - Agente 3: Posición (10, 0), Estado Sin caja
#   - Agente 4: Posición (3, 3), Estado Con caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 3)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 0)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (7, 4)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 15)
# Agente 4 colocó una caja en (2, 3)
# Agente 4 se movió a (3, 2)
# Paso 3302:
#   - Agente 0: Posición (7, 15), Estado Sin caja
#   - Agente 1: Posición (10, 3), Estado Sin caja
#   - Agente 2: Posición (7, 4), Estado Sin caja
#   - Agente 3: Posición (9, 0), Estado Sin caja
#   - Agente 4: Posición (3, 2), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 14)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 1)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (7, 5)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (3, 1)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 4)
# Paso 3303:
#   - Agente 0: Posición (7, 14), Estado Sin caja
#   - Agente 1: Posición (10, 4), Estado Sin caja
#   - Agente 2: Posición (7, 5), Estado Sin caja
#   - Agente 3: Posición (9, 1), Estado Sin caja
#   - Agente 4: Posición (3, 1), Estado Sin caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 5)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (8, 5)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (4, 1)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 0)
# Paso 3304:
#   - Agente 0: Posición (6, 14), Estado Sin caja
#   - Agente 1: Posición (10, 5), Estado Sin caja
#   - Agente 2: Posición (8, 5), Estado Sin caja
#   - Agente 3: Posición (9, 0), Estado Sin caja
#   - Agente 4: Posición (4, 1), Estado Sin caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 6)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (10, 0)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (5, 1)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (5, 14)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (9, 5)
# Paso 3305:
#   - Agente 0: Posición (5, 14), Estado Sin caja
#   - Agente 1: Posición (10, 6), Estado Sin caja
#   - Agente 2: Posición (9, 5), Estado Sin caja
#   - Agente 3: Posición (10, 0), Estado Sin caja
#   - Agente 4: Posición (5, 1), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (5, 15)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (10, 1)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 5)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (6, 1)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (8, 5)
# Paso 3306:
#   - Agente 0: Posición (5, 15), Estado Sin caja
#   - Agente 1: Posición (10, 5), Estado Sin caja
#   - Agente 2: Posición (8, 5), Estado Sin caja
#   - Agente 3: Posición (10, 1), Estado Sin caja
#   - Agente 4: Posición (6, 1), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (6, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 5)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (8, 6)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (5, 16)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (11, 1)
# Paso 3307:
#   - Agente 0: Posición (5, 16), Estado Sin caja
#   - Agente 1: Posición (11, 5), Estado Sin caja
#   - Agente 2: Posición (8, 6), Estado Sin caja
#   - Agente 3: Posición (11, 1), Estado Sin caja
#   - Agente 4: Posición (6, 2), Estado Sin caja
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (10, 1)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 16)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (9, 6)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (5, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 4)
# Paso 3308:
#   - Agente 0: Posición (6, 16), Estado Sin caja
#   - Agente 1: Posición (11, 4), Estado Sin caja
#   - Agente 2: Posición (9, 6), Estado Sin caja
#   - Agente 3: Posición (10, 1), Estado Sin caja
#   - Agente 4: Posición (5, 2), Estado Sin caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 4)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (9, 7)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (10, 2)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (4, 2)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 17)
# Paso 3309:
#   - Agente 0: Posición (6, 17), Estado Sin caja
#   - Agente 1: Posición (10, 4), Estado Sin caja
#   - Agente 2: Posición (9, 7), Estado Sin caja
#   - Agente 3: Posición (10, 2), Estado Sin caja
#   - Agente 4: Posición (4, 2), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 17)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (9, 8)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (3, 2)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (9, 4)
# Paso 3310:
#   - Agente 0: Posición (7, 17), Estado Sin caja
#   - Agente 1: Posición (9, 4), Estado Sin caja
#   - Agente 2: Posición (9, 8), Estado Sin caja
#   - Agente 3: Posición (9, 2), Estado Sin caja
#   - Agente 4: Posición (3, 2), Estado Sin caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (7, 18)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 3)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (8, 8)
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (3, 3)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (9, 5)
# Paso 3311:
#   - Agente 0: Posición (7, 18), Estado Sin caja
#   - Agente 1: Posición (9, 5), Estado Sin caja
#   - Agente 2: Posición (8, 8), Estado Sin caja
#   - Agente 3: Posición (9, 3), Estado Sin caja
#   - Agente 4: Posición (3, 3), Estado Sin caja
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 5)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (7, 8)
# Agente 4 recogió una caja de (2, 3)
# Agente 4 se movió a (3, 2)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 18)
# Paso 3312:
#   - Agente 0: Posición (6, 18), Estado Sin caja
#   - Agente 1: Posición (10, 5), Estado Sin caja
#   - Agente 2: Posición (7, 8), Estado Sin caja
#   - Agente 3: Posición (9, 2), Estado Sin caja
#   - Agente 4: Posición (3, 2), Estado Con caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 6)
# Agente 4 colocó una caja en (2, 2)
# Agente 4 se movió a (4, 2)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (8, 2)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (8, 8)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (5, 18)
# Paso 3313:
#   - Agente 0: Posición (5, 18), Estado Sin caja
#   - Agente 1: Posición (10, 6), Estado Sin caja
#   - Agente 2: Posición (8, 8), Estado Sin caja
#   - Agente 3: Posición (8, 2), Estado Sin caja
#   - Agente 4: Posición (4, 2), Estado Sin caja
# Agente 4 no encontró caja para recoger
# Agente 4 se movió a (3, 2)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 2)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (4, 18)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 7)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (8, 7)
# Paso 3314:
#   - Agente 0: Posición (4, 18), Estado Sin caja
#   - Agente 1: Posición (10, 7), Estado Sin caja
#   - Agente 2: Posición (8, 7), Estado Sin caja
#   - Agente 3: Posición (9, 2), Estado Sin caja
#   - Agente 4: Posición (3, 2), Estado Sin caja
# Agente 4 recogió una caja de (2, 2)
# Agente 4 se movió a (2, 2)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (9, 3)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (7, 7)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (3, 18)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 7)
# Paso 3315:
#   - Agente 0: Posición (3, 18), Estado Sin caja
#   - Agente 1: Posición (11, 7), Estado Sin caja
#   - Agente 2: Posición (7, 7), Estado Sin caja
#   - Agente 3: Posición (9, 3), Estado Sin caja
#   - Agente 4: Posición (2, 2), Estado Con caja
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (8, 3)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (2, 18)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 6)
# Agente 4 colocó una caja en (1, 2)
# Agente 4 se movió a (1, 2)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (7, 8)
# Paso 3316:
#   - Agente 0: Posición (2, 18), Estado Sin caja
#   - Agente 1: Posición (11, 6), Estado Sin caja
#   - Agente 2: Posición (7, 8), Estado Sin caja
#   - Agente 3: Posición (8, 3), Estado Sin caja
#   - Agente 4: Posición (1, 2), Estado Sin caja
# Agente 4 recogió una caja de (1, 2)
# Agente 4 se movió a (1, 1)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (3, 18)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (7, 9)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (7, 3)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (10, 6)
# Paso 3317:
#   - Agente 0: Posición (3, 18), Estado Sin caja
#   - Agente 1: Posición (10, 6), Estado Sin caja
#   - Agente 2: Posición (7, 9), Estado Sin caja
#   - Agente 3: Posición (7, 3), Estado Sin caja
#   - Agente 4: Posición (1, 1), Estado Con caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (4, 18)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (6, 9)
# Agente 4 colocó una caja en (1, 1)
# Agente 4 se movió a (1, 0)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (6, 3)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 6)
# Paso 3318:
#   - Agente 0: Posición (4, 18), Estado Sin caja
#   - Agente 1: Posición (11, 6), Estado Sin caja
#   - Agente 2: Posición (6, 9), Estado Sin caja
#   - Agente 3: Posición (6, 3), Estado Sin caja
#   - Agente 4: Posición (1, 0), Estado Sin caja
# Agente 4 recogió una caja de (1, 1)
# Agente 4 se movió a (1, 1)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (7, 3)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 7)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (6, 8)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (4, 19)
# Paso 3319:
#   - Agente 0: Posición (4, 19), Estado Sin caja
#   - Agente 1: Posición (11, 7), Estado Sin caja
#   - Agente 2: Posición (6, 8), Estado Sin caja
#   - Agente 3: Posición (7, 3), Estado Sin caja
#   - Agente 4: Posición (1, 1), Estado Con caja
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (12, 7)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 8)
# Agente 4 colocó una caja en (1, 1)
# Agente 4 se movió a (1, 2)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (6, 3)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (5, 19)
# Paso 3320:
#   - Agente 0: Posición (5, 19), Estado Sin caja
#   - Agente 1: Posición (12, 7), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (6, 3), Estado Sin caja
#   - Agente 4: Posición (1, 2), Estado Sin caja
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (6, 8)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (6, 2)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 7)
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 19)
# Agente 4 recogió una caja de (1, 2)
# Agente 4 se movió a (1, 1)
# Paso 3321:
#   - Agente 0: Posición (6, 19), Estado Sin caja
#   - Agente 1: Posición (11, 7), Estado Sin caja
#   - Agente 2: Posición (6, 8), Estado Sin caja
#   - Agente 3: Posición (6, 2), Estado Sin caja
#   - Agente 4: Posición (1, 1), Estado Con caja
# Agente 0 no encontró caja para recoger
# Agente 0 se movió a (6, 18)
# Agente 2 no encontró caja para recoger
# Agente 2 se movió a (5, 8)
# Agente 4 colocó una caja en (1, 1)
# Agente 4 se movió a (0, 1)
# Agente 3 no encontró caja para recoger
# Agente 3 se movió a (6, 1)
# Agente 1 no encontró caja para recoger
# Agente 1 se movió a (11, 6)
# Paso 3322:
#   - Agente 0: Posición (6, 18), Estado Sin caja
#   - Agente 1: Posición (11, 6), Estado Sin caja
#   - Agente 2: Posición (5, 8), Estado Sin caja
#   - Agente 3: Posición (6, 1), Estado Sin caja
#   - Agente 4: Posición (0, 1), Estado Sin caja

# %%
# Resumen final
num_cells_with_5 = sum(1 for count in model.cell_state.values() if count == MAX_BOXES_PER_CELL)
num_cells_with_0 = sum(1 for count in model.cell_state.values() if count == 0)
total_steps = model.schedule.steps
print(f"Total de pasos para completar la simulación: {total_steps}")
print(f"Número de celdas con 5 cajas: {num_cells_with_5}")
print(f"Número de celdas con 0 cajas: {num_cells_with_0}")
# Out:
# Total de pasos para completar la simulación: 3322
# Número de celdas con 5 cajas: 40
# Número de celdas con 0 cajas: 360
